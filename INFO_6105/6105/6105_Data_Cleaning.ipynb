# %%
import numpy as np
import pandas as pd
# loandata = pd.DataFrame('products.csv')
df1 = pd.read_csv("L'Oreal Paris_Product.csv",encoding='latin-1');
df2 = pd.read_csv("Test_User_L'Oreal Paris_Product .csv",encoding='latin-1');
df3 = pd.read_csv("Twitter_API_output.csv",encoding='latin-1');
# df = pd.merge(df1, df2,  how= 'left' ) 
data = pd.concat([df1,df2,df3],axis=1)

# %%
data
# Out:
#     Unnamed: 0 L'Oreal Paris_Product_names L'Oreal Paris_Product_price  \
# 0            0             Colour RicheÂ®                        $9.99
# 1            1            Rouge Signature                       $11.99
# 2            2          True MatchÂ® Lumi                       $14.99
# 3            3                  Unlimited                       $12.99
# 4            4               InfallibleÂ®                       $14.99
# 5            5               InfallibleÂ®                       $12.99
# 6            6                  Unlimited                       $12.99
# 7            7              UnbelievaBrow                       $16.99
# 8            8             Colour RicheÂ®                        $9.99
# 9            9      Colour Riche Lipstick                        $9.99
# 10          10                 Voluminous                        $9.99
# 11          11               InfallibleÂ®                        $9.99
# ...

# %%
data = data.fillna('unavailable')

# %%
data["L'Oreal Paris_Product_price"].apply(lambda x: x. isdigit ())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: L'Oreal Paris_Product_price, dtype: bool

# %%
data['Test_User_Gender']= data['Test_User_Gender'].map(str.strip)

# %%
data
# Out:
#     Unnamed: 0 L'Oreal Paris_Product_names L'Oreal Paris_Product_price  \
# 0            0             Colour RicheÂ®                        $9.99
# 1            1            Rouge Signature                       $11.99
# 2            2          True MatchÂ® Lumi                       $14.99
# 3            3                  Unlimited                       $12.99
# 4            4               InfallibleÂ®                       $14.99
# 5            5               InfallibleÂ®                       $12.99
# 6            6                  Unlimited                       $12.99
# 7            7              UnbelievaBrow                       $16.99
# 8            8             Colour RicheÂ®                        $9.99
# 9            9      Colour Riche Lipstick                        $9.99
# 10          10                 Voluminous                        $9.99
# 11          11               InfallibleÂ®                        $9.99
# ...

# %%
data = data.drop_duplicates()

# %%
data.describe().astype(np.int64).T
# Out:
#                               count  mean  std  min  25%  50%  75%  max
# Unnamed: 0                       21    10    6    0    5   10   15   20
# Unnamed: 0                       21    10    6    0    5   10   15   20
# Test_User_Age                    21    23    2   19   22   23   25   27
# Twitter_Search_Result_Counts     21     6   28    0    0    0    0  130

# %%
# loandata.dtypes
data = data.replace([30,18],data['Test_User_Age'].mean())
data = data.replace("\n\n\n\n\n\n","unavailable")

# %%
data['Test_User_Name']=data['Test_User_Name'].map(str.title)

# %%
data
# Out:
#     Unnamed: 0 L'Oreal Paris_Product_names L'Oreal Paris_Product_price  \
# 0     0.000000             Colour RicheÂ®                        $9.99
# 1     1.000000            Rouge Signature                       $11.99
# 2     2.000000          True MatchÂ® Lumi                       $14.99
# 3     3.000000                  Unlimited                       $12.99
# 4     4.000000               InfallibleÂ®                       $14.99
# 5     5.000000               InfallibleÂ®                       $12.99
# 6     6.000000                  Unlimited                       $12.99
# 7     7.000000              UnbelievaBrow                       $16.99
# 8     8.000000             Colour RicheÂ®                        $9.99
# 9     9.000000      Colour Riche Lipstick                        $9.99
# 10   10.000000                 Voluminous                        $9.99
# 11   11.000000               InfallibleÂ®                        $9.99
# ...

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of    L'Oreal Paris_Product_names L'Oreal Paris_Product_price  \
# 0              Colour RicheÂ®                        $9.99
# 1             Rouge Signature                       $11.99
# 2           True MatchÂ® Lumi                       $14.99
# 3                   Unlimited                       $12.99
# 4                InfallibleÂ®                       $14.99
# 5                InfallibleÂ®                       $12.99
# 6                   Unlimited                       $12.99
# 7               UnbelievaBrow                       $16.99
# 8              Colour RicheÂ®                        $9.99
# 9       Colour Riche Lipstick                        $9.99
# 10                 Voluminous                        $9.99
# 11               InfallibleÂ®                        $9.99
# 12               InfallibleÂ®                       $12.99
# 13               InfallibleÂ®                        $9.99
# ...

# %%
data
# Out:
#    L'Oreal Paris_Product_names L'Oreal Paris_Product_price  \
# 0              Colour RicheÂ®                        $9.99
# 1             Rouge Signature                       $11.99
# 2           True MatchÂ® Lumi                       $14.99
# 3                   Unlimited                       $12.99
# 4                InfallibleÂ®                       $14.99
# 5                InfallibleÂ®                       $12.99
# 6                   Unlimited                       $12.99
# 7               UnbelievaBrow                       $16.99
# 8              Colour RicheÂ®                        $9.99
# 9       Colour Riche Lipstick                        $9.99
# 10                 Voluminous                        $9.99
# 11               InfallibleÂ®                        $9.99
# 12               InfallibleÂ®                       $12.99
# 13               InfallibleÂ®                        $9.99
# 14                 Voluminous                        $9.99
# ...

# %%
data.to_csv("All information about L'Oreal Paris_Product.csv")
