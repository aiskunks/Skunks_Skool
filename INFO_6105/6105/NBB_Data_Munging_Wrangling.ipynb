# %% [markdown]
# # NBB

# %% [markdown]
# ## Data munging
#
# Data munging (sometimes referred to as data wrangling) is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.datasets import load_boston

# Make plots larger
plt.rcParams['figure.figsize'] = (15, 9)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x="time", y="total_bill", data=tips);

# %%
sns.boxplot(x=tips["total_bill"])

# %%
tips['tip'].hist(bins=33)

# %%
sns.distplot(tips['tip'])

# %%
dataset = load_boston()
boston =  pd.DataFrame(dataset.data, columns=dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ### Check missing values in the dataset

# %%
 sum(boston['NOX'].isnull())
# Out:
# 0

# %%
boston.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %% [markdown]
# ### Check the range of values in the dataset

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %% [markdown]
# ## Pima Indians Diabetes Dataset
#
# [Pima Indians Diabetes Dataset](https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes) is known to have missing values.
#
# Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage. ADAP is an adaptive learning routine that generates and executes digital analogs of perceptron-like devices. It is a unique algorithm; see the paper for details.
#
#
# Attribute Information:
#
# 1. Number of times pregnant
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-Hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 8. Age (years)
# 9. Class variable (0 or 1)
#
#
# Relevant Papers:
#
# Smith, J.W., Everhart, J.E., Dickson, W.C., Knowler, W.C., & Johannes, R.S. (1988). Using the ADAP learning algorithm to forecast the onset of diabetes mellitus. In Proceedings of the Symposium on Computer Applications and Medical Care} (pp. 261--265). IEEE Computer Society Press.

# %%
pima = pd.read_csv("http://nikbearbrown.com/YouTube/MachineLearning/DATA/pima-indians-diabetes.csv", sep=',')
pima.head()
# Out:
#    times_pregnant  plasma_glucose  blood_pressure  \
# 0               6           148.0            72.0
# 1               1            85.0            66.0
# 2               8           183.0            64.0
# 3               1            89.0            66.0
# 4               0           137.0            40.0
#
#    triceps_skin_fold_thickness  serum_insulin   bmi  diabetes_pedigree   age  \
# 0                           35            0.0  33.6              0.627  50.0
# 1                           29            0.0  26.6              0.351  31.0
# 2                            0            0.0  23.3              0.672  32.0
# 3                           23           94.0  28.1              0.167  21.0
# 4                           35          168.0  43.1              2.288  33.0
#
#    class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
pima.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# times_pregnant                 0
# plasma_glucose                 2
# blood_pressure                 3
# triceps_skin_fold_thickness    0
# serum_insulin                  1
# bmi                            1
# diabetes_pedigree              0
# age                            2
# class                          0
# dtype: int64

# %%
pima.isnull().sum()
# Out:
# times_pregnant                 0
# plasma_glucose                 2
# blood_pressure                 3
# triceps_skin_fold_thickness    0
# serum_insulin                  1
# bmi                            1
# diabetes_pedigree              0
# age                            2
# class                          0
# dtype: int64

# %%
pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# times_pregnant                 768 non-null int64
# plasma_glucose                 766 non-null float64
# blood_pressure                 765 non-null float64
# triceps_skin_fold_thickness    768 non-null int64
# serum_insulin                  767 non-null float64
# bmi                            767 non-null float64
# diabetes_pedigree              768 non-null float64
# age                            766 non-null float64
# class                          768 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
pima.isnull().sum()
# Out:
# times_pregnant                 0
# plasma_glucose                 2
# blood_pressure                 3
# triceps_skin_fold_thickness    0
# serum_insulin                  1
# bmi                            1
# diabetes_pedigree              0
# age                            2
# class                          0
# dtype: int64

# %%
(pima['serum_insulin'] == 0).sum()
# Out:
# 374

# %%
(pima['serum_insulin'] < 50).sum()
# Out:
# 411

# %%
pima_bak=pima.copy()

# %% [markdown]
# ## How to fill missing values?

# %%
pima_bak.isnull().sum()
# Out:
# times_pregnant                 0
# plasma_glucose                 2
# blood_pressure                 3
# triceps_skin_fold_thickness    0
# serum_insulin                  1
# bmi                            1
# diabetes_pedigree              0
# age                            2
# class                          0
# dtype: int64

# %%
pima_bak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# times_pregnant                 768 non-null int64
# plasma_glucose                 766 non-null float64
# blood_pressure                 765 non-null float64
# triceps_skin_fold_thickness    768 non-null int64
# serum_insulin                  767 non-null float64
# bmi                            767 non-null float64
# diabetes_pedigree              768 non-null float64
# age                            766 non-null float64
# class                          768 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
# drop rows with missing values
pima_bak.dropna(inplace=True)

# %%
pima_bak.isnull().sum()
# Out:
# times_pregnant                 0
# plasma_glucose                 0
# blood_pressure                 0
# triceps_skin_fold_thickness    0
# serum_insulin                  0
# bmi                            0
# diabetes_pedigree              0
# age                            0
# class                          0
# dtype: int64

# %%
pima_bak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 759 entries, 0 to 767
# Data columns (total 9 columns):
# times_pregnant                 759 non-null int64
# plasma_glucose                 759 non-null float64
# blood_pressure                 759 non-null float64
# triceps_skin_fold_thickness    759 non-null int64
# serum_insulin                  759 non-null float64
# bmi                            759 non-null float64
# diabetes_pedigree              759 non-null float64
# age                            759 non-null float64
# class                          759 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 59.3 KB

# %%
(pima_bak['serum_insulin'] < 50).sum()
# Out:
# 406

# %%
pima_bak.loc[pima_bak['serum_insulin'] < 50]
# Out:
#      times_pregnant  plasma_glucose  blood_pressure  \
# 0                 6           148.0            72.0
# 1                 1            85.0            66.0
# 2                 8           183.0            64.0
# 5                 5           116.0            74.0
# 7                10           115.0             0.0
# 9                 8           125.0            96.0
# 10                4           110.0            92.0
# 11               10           168.0            74.0
# 12               10           139.0            80.0
# 15                7           100.0             0.0
# 17                7           107.0            74.0
# 21                8            99.0            84.0
# 22                7           196.0            90.0
# 23                9           119.0            80.0
# 26                7           147.0            76.0
# 29                5           117.0            92.0
# 30                5           109.0            75.0
# 33                6            92.0            92.0
# 34               10           122.0            78.0
# 36               11           138.0            76.0
# 37                9           102.0            76.0
# 38                2            90.0            68.0
# 41                7           133.0            84.0
# 42                7           106.0            92.0
# 44                7           159.0            64.0
# 45                0           180.0            66.0
# 46                1           146.0            56.0
# 47                2            71.0            70.0
# 48                7           103.0            66.0
# 49                7           105.0             0.0
# ..              ...             ...             ...
# 714               3           102.0            74.0
# 717              10            94.0            72.0
# 719               5            97.0            76.0
# 720               4            83.0            86.0
# 724               1           111.0            94.0
# 725               4           112.0            78.0
# 727               0           141.0            84.0
# 728               2           175.0            88.0
# 729               2            92.0            52.0
# 731               8           120.0            86.0
# 734               2           105.0            75.0
# 735               4            95.0            60.0
# 737               8            65.0            72.0
# 739               1           102.0            74.0
# 743               9           140.0            94.0
# 746               1           147.0            94.0
# 749               6           162.0            62.0
# 750               4           136.0            70.0
# 752               3           108.0            62.0
# 754               8           154.0            78.0
# 756               7           137.0            90.0
# 757               0           123.0            72.0
# 758               1           106.0            76.0
# 759               6           190.0            92.0
# 760               2            88.0            58.0
# 761               9           170.0            74.0
# 762               9            89.0            62.0
# 764               2           122.0            70.0
# 766               1           126.0            60.0
# 767               1            93.0            70.0
#
#      triceps_skin_fold_thickness  serum_insulin   bmi  diabetes_pedigree  \
# 0                             35            0.0  33.6              0.627
# 1                             29            0.0  26.6              0.351
# 2                              0            0.0  23.3              0.672
# 5                              0            0.0  25.6              0.201
# 7                              0            0.0  35.3              0.134
# 9                              0            0.0   0.0              0.232
# 10                             0            0.0  37.6              0.191
# 11                             0            0.0  38.0              0.537
# 12                             0            0.0  27.1              1.441
# 15                             0            0.0  30.0              0.484
# 17                             0            0.0  29.6              0.254
# 21                             0            0.0  35.4              0.388
# 22                             0            0.0  39.8              0.451
# 23                            35            0.0  29.0              0.263
# 26                             0            0.0  39.4              0.257
# 29                             0            0.0  34.1              0.337
# 30                            26            0.0  36.0              0.546
# 33                             0            0.0  19.9              0.188
# 34                            31            0.0  27.6              0.512
# 36                             0            0.0  33.2              0.420
# 37                            37            0.0  32.9              0.665
# 38                            42            0.0  38.2              0.503
# 41                             0            0.0  40.2              0.696
# 42                            18            0.0  22.7              0.235
# 44                             0            0.0  27.4              0.294
# 45                            39            0.0  42.0              1.893
# 46                             0            0.0  29.7              0.564
# 47                            27            0.0  28.0              0.586
# 48                            32            0.0  39.1              0.344
# 49                             0            0.0   0.0              0.305
# ..                           ...            ...   ...                ...
# 714                            0            0.0  29.5              0.121
# 717                           18            0.0  23.1              0.595
# 719                           27            0.0  35.6              0.378
# 720                           19            0.0  29.3              0.317
# 724                            0            0.0  32.8              0.265
# 725                           40            0.0  39.4              0.236
# 727                           26            0.0  32.4              0.433
# 728                            0            0.0  22.9              0.326
# 729                            0            0.0  30.1              0.141
# 731                            0            0.0  28.4              0.259
# 734                            0            0.0  23.3              0.560
# 735                           32            0.0  35.4              0.284
# 737                           23            0.0  32.0              0.600
# 739                            0            0.0  39.5              0.293
# 743                            0            0.0  32.7              0.734
# 746                           41            0.0  49.3              0.358
# 749                            0            0.0  24.3              0.178
# 750                            0            0.0  31.2              1.182
# 752                           24            0.0  26.0              0.223
# 754                           32            0.0  32.4              0.443
# 756                           41            0.0  32.0              0.391
# 757                            0            0.0  36.3              0.258
# 758                            0            0.0  37.5              0.197
# 759                            0            0.0  35.5              0.278
# 760                           26           16.0  28.4              0.766
# 761                           31            0.0  44.0              0.403
# 762                            0            0.0  22.5              0.142
# 764                           27            0.0  36.8              0.340
# 766                            0            0.0  30.1              0.349
# 767                           31            0.0  30.4              0.315
#
#       age  class
# 0    50.0      1
# 1    31.0      0
# 2    32.0      1
# 5    30.0      0
# 7    29.0      0
# 9    54.0      1
# 10   30.0      0
# 11   34.0      1
# 12   57.0      0
# 15   32.0      1
# 17   31.0      1
# 21   50.0      0
# 22   41.0      1
# 23   29.0      1
# 26   43.0      1
# 29   38.0      0
# 30   60.0      0
# 33   28.0      0
# 34   45.0      0
# 36   35.0      0
# 37   46.0      1
# 38   27.0      1
# 41   37.0      0
# 42   48.0      0
# 44   40.0      0
# 45   25.0      1
# 46   29.0      0
# 47   22.0      0
# 48   31.0      1
# 49   24.0      0
# ..    ...    ...
# 714  32.0      0
# 717  56.0      0
# 719  52.0      1
# 720  34.0      0
# 724  45.0      0
# 725  38.0      0
# 727  22.0      0
# 728  22.0      0
# 729  22.0      0
# 731  22.0      1
# 734  53.0      0
# 735  28.0      0
# 737  42.0      0
# 739  42.0      1
# 743  45.0      1
# 746  27.0      1
# 749  50.0      1
# 750  22.0      1
# 752  25.0      0
# 754  45.0      1
# 756  39.0      0
# 757  52.0      1
# 758  26.0      0
# 759  66.0      1
# 760  22.0      0
# 761  43.0      1
# 762  33.0      0
# 764  27.0      0
# 766  47.0      1
# 767  23.0      0
#
# [406 rows x 9 columns]

# %%
pima_bak['serum_insulin'].loc[pima_bak['serum_insulin'] < 50]
# Out:
# 0       0.0
# 1       0.0
# 2       0.0
# 5       0.0
# 7       0.0
# 9       0.0
# 10      0.0
# 11      0.0
# 12      0.0
# 15      0.0
# 17      0.0
# 21      0.0
# 22      0.0
# 23      0.0
# 26      0.0
# 29      0.0
# 30      0.0
# 33      0.0
# 34      0.0
# 36      0.0
# 37      0.0
# 38      0.0
# 41      0.0
# 42      0.0
# 44      0.0
# 45      0.0
# 46      0.0
# 47      0.0
# 48      0.0
# 49      0.0
#        ...
# 714     0.0
# 717     0.0
# 719     0.0
# 720     0.0
# 724     0.0
# 725     0.0
# 727     0.0
# 728     0.0
# 729     0.0
# 731     0.0
# 734     0.0
# 735     0.0
# 737     0.0
# 739     0.0
# 743     0.0
# 746     0.0
# 749     0.0
# 750     0.0
# 752     0.0
# 754     0.0
# 756     0.0
# 757     0.0
# 758     0.0
# 759     0.0
# 760    16.0
# 761     0.0
# 762     0.0
# 764     0.0
# 766     0.0
# 767     0.0
# Name: serum_insulin, Length: 406, dtype: float64

# %%
pima_bak['serum_insulin'].mean()
# Out:
# 79.75230566534914

# %%
pima_bak.head()
# Out:
#    times_pregnant  plasma_glucose  blood_pressure  \
# 0               6           148.0            72.0
# 1               1            85.0            66.0
# 2               8           183.0            64.0
# 3               1            89.0            66.0
# 4               0           137.0            40.0
#
#    triceps_skin_fold_thickness  serum_insulin   bmi  diabetes_pedigree   age  \
# 0                           35            0.0  33.6              0.627  50.0
# 1                           29            0.0  26.6              0.351  31.0
# 2                            0            0.0  23.3              0.672  32.0
# 3                           23           94.0  28.1              0.167  21.0
# 4                           35          168.0  43.1              2.288  33.0
#
#    class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
pima_bak.loc[pima_bak['serum_insulin'] < 50, 'serum_insulin'] = pima_bak['serum_insulin'].mean()

# %%
(pima_bak['serum_insulin'] < 50).sum()
# Out:
# 0

# %%
pima_bak.head()
# Out:
#    times_pregnant  plasma_glucose  blood_pressure  \
# 0               6           148.0            72.0
# 1               1            85.0            66.0
# 2               8           183.0            64.0
# 3               1            89.0            66.0
# 4               0           137.0            40.0
#
#    triceps_skin_fold_thickness  serum_insulin   bmi  diabetes_pedigree   age  \
# 0                           35      79.752306  33.6              0.627  50.0
# 1                           29      79.752306  26.6              0.351  31.0
# 2                            0      79.752306  23.3              0.672  32.0
# 3                           23      94.000000  28.1              0.167  21.0
# 4                           35     168.000000  43.1              2.288  33.0
#
#    class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
pima_bak['serum_insulin'].fillna(pima_bak['serum_insulin'].mean(), inplace=True)

# %% [markdown]
# ## Data cleaning checklist
#
#  * Save original data
#  * Identify missing data
#  * Identify placeholder data (e.g. 0's for NA's)
#  * Identify outliers
#  * Check for overall plausibility and errors (e.g., typos, unreasonable ranges)
#  * Identify highly correlated variables
#  * Identify variables with (nearly) no variance
#  * Identify variables with strange names or values
#  * Check variable classes (eg. Characters vs factors)
#  * Remove/transform some variables (maybe your model does not like categorial variables)
#  * Rename some variables or values (if not all data is useful)
#  * Check some overall pattern (statistical/ numerical summaries)
#  * Possibly center/scale variables

# %% [markdown]
# Last update September 5, 2017
