# %%
# !pip install ascii
# Out:
# Collecting ascii
#   Downloading ascii-3.6.tar.gz (2.4 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from ascii) (7.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from ascii) (1.24.3)
# Building wheels for collected packages: ascii
#   Building wheel for ascii (setup.py) ... done
#   Created wheel for ascii: filename=ascii-3.6-py3-none-any.whl size=3489 sha256=03836a2a8399bbc55d3b2c65910639d514576b70cd19ab24850ec92f322380af
#   Stored in directory: /root/.cache/pip/wheels/95/b5/c7/c30b5529ebc28f3cf45b8ed94092754085092747ec42cdf2c8
# Successfully built ascii
# Installing collected packages: ascii
# Successfully installed ascii-3.6

# %%
import string
characters=string.printable

# %%
characters
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
alphabet='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
alphabet
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
