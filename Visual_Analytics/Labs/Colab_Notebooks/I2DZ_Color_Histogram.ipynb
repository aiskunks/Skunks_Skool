# %% [markdown]
# # Color Histogram
#
# Color Histogram demo.

# %%
# Bring in python image analysis libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# !pip install git+https://github.com/tody411/ColorHistogram.git
# Out:
# Collecting git+https://github.com/tody411/ColorHistogram.git
#   Cloning https://github.com/tody411/ColorHistogram.git to /tmp/pip-req-build-p42ry99z
#   Running command git clone -q https://github.com/tody411/ColorHistogram.git /tmp/pip-req-build-p42ry99z
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from color-histogram==0.5) (0.6.2)
# Building wheels for collected packages: color-histogram
#   Building wheel for color-histogram (setup.py) ... done
#   Created wheel for color-histogram: filename=color_histogram-0.5-cp36-none-any.whl size=23234 sha256=10bae3986310a7e6c1c98b1bce5233893a9cc1d9e04742db6a1290d1859b75aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3fw2a5au/wheels/75/df/fe/d73eea7a9ab305b72186ff3ed898873a6fdb62463f850318ba
# Successfully built color-histogram
# Installing collected packages: color-histogram
# Successfully installed color-histogram-0.5

# %%
from color_histogram.io_util.image import loadRGB
from color_histogram.core.hist_1d import Hist1D
from color_histogram.core.hist_2d import Hist2D
from color_histogram.core.hist_3d import Hist3D

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b761e42-59a2-4d39-9e69-d43c74803600" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b761e42-59a2-4d39-9e69-d43c74803600">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amjauduzuxs.jpg to amjauduzuxs (2).jpg
# Saving cdambaqalqn.jpg to cdambaqalqn (2).jpg
# Saving dabtjzgoklo.jpg to dabtjzgoklo (2).jpg
# Saving fbrsebevymu.jpg to fbrsebevymu (2).jpg
# Saving mqtvzimfxve.jpg to mqtvzimfxve (2).jpg
# Saving tbtfkmgzkda.jpg to tbtfkmgzkda (2).jpg

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "amjauduzuxs.jpg" with length 22407 bytes
# User uploaded file "cdambaqalqn.jpg" with length 19814 bytes
# User uploaded file "dabtjzgoklo.jpg" with length 10947 bytes
# User uploaded file "fbrsebevymu.jpg" with length 15748 bytes
# User uploaded file "mqtvzimfxve.jpg" with length 117183 bytes
# User uploaded file "tbtfkmgzkda.jpg" with length 22868 bytes

# %%
print(uploaded.keys())
plt.figure()
images=[]
images_hist=[]
files=list(uploaded.keys())
for name in files:
  img=mpimg.imread(name)
  image = loadRGB(image_file)
  images.append(img)
  images_hist.append(image)  

plt.imshow(images[0])
# Out:
# dict_keys(['amjauduzuxs.jpg', 'cdambaqalqn.jpg', 'dabtjzgoklo.jpg', 'fbrsebevymu.jpg', 'mqtvzimfxve.jpg', 'tbtfkmgzkda.jpg'])

# %%
import PIL
from PIL import Image

# %%
im = Image.open(files[0])  
w, h = im.size  
colors = im.getcolors(w*h)

# %%
def hexencode(rgb):
    r=rgb[0]
    g=rgb[1]
    b=rgb[2]
    return '#%02x%02x%02x' % (r,g,b)

# %%
for idx, c in enumerate(colors):
    plt.bar(idx, c[0], color=hexencode(c[1]))
plt.show()

# %%
print (files)
# Out:
# ['amjauduzuxs.jpg', 'cdambaqalqn.jpg', 'dabtjzgoklo.jpg', 'fbrsebevymu.jpg', 'mqtvzimfxve.jpg', 'tbtfkmgzkda.jpg']

# %%
# 16 bins, Lab color space, target channel L ('Lab'[0])

image = loadRGB(files[0])

# 16 bins, Lab color space, target channel L ('Lab'[0])
hist2D = Hist2D(image, num_bins=32, color_space='hsv', channels=[0, 1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-880b2d28bc06> in <module>()
#       4
#       5 # 16 bins, Lab color space, target channel L ('Lab'[0])
# ----> 6 hist2D = Hist2D(image, num_bins=32, color_space='hsv', channels=[0, 1])
#
# /usr/local/lib/python3.6/dist-packages/color_histogram/core/hist_2d.py in __init__(self, image, num_bins, alpha, color_space, channels)
#      22     #  @param channels       target color channels. [0, 1] with 'hsv' means (h, s) channels.
#      23     def __init__(self, image, num_bins=16, alpha=0.1, color_space='hsv', channels=[0, 1]):
# ---> 24         self._computeTargetPixels(image, color_space, channels)
#      25         self._num_bins = num_bins
#      26         self._alpha = alpha
#
# /usr/local/lib/python3.6/dist-packages/color_histogram/core/hist_2d.py in _computeTargetPixels(self, image, color_space, channels)
#      64     def _computeTargetPixels(self, image, color_space, channels):
#      65         color_pixels = ColorPixels(image)
# ---> 66         self._pixels = color_pixels.pixels(color_space)[:, channels]
#      67         self._rgb_pixels = color_pixels.rgb()
#      68
#
# /usr/local/lib/python3.6/dist-packages/color_histogram/core/color_pixels.py in pixels(self, color_space)
#      56         if color_space == "hsv":
#      57             image = rgb2hsv(self._image)
# ---> 58         return self._image2pixels(image)
#      59
#      60     def _image2pixels(self, image):
#
# /usr/local/lib/python3.6/dist-packages/color_histogram/core/color_pixels.py in _image2pixels(self, image)
#      66         h, w, cs = image.shape
#      67         step = h * w / self._num_pixels
# ---> 68         return image.reshape((-1, cs))[::step]
#      69
#      70
#
# TypeError: slice indices must be integers or None or have an __index__ method
