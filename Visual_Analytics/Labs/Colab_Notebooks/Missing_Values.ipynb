# %%
import pandas as pd
import numpy as np
np.random.seed(5)

# %%
df= pd.read_csv("https://raw.githubusercontent.com/nikbearbrown/Google_Colab/master/pima_diabetes_to_clean.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6    148.0           72.0  ...                     0.627   50        1
# 1            1     85.0           66.0  ...                     0.351   31        0
# 2            8    183.0           64.0  ...                     0.672   32        1
# 3            1     89.0           66.0  ...                     0.167   21        0
# 4            0    137.0           40.0  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  766.000000  ...  768.000000  768.000000
# mean      3.845052  120.934726  ...   33.240885    0.348958
# std       3.369578   31.993560  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.750000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
print(df.shape)
# Out:
# (768, 9)

# %%
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# Pregnancies                 0
# Glucose                     2
# BloodPressure               4
# SkinThickness               2
# Insulin                     1
# BMI                         2
# DiabetesPedigreeFunction    2
# Age                         0
# Outcome                     0
# dtype: int64

# %%
zero_values_count = df.isin([0]).sum()
zero_values_count
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
# Note this won't work df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0, np.nan, inplace=True)
# df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0, np.nan)
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0, np.median)

# %%
zero_values_count = df.isin([0]).sum()
zero_values_count
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  761.000000  ...  768.000000  768.000000
# mean      3.845052  121.729304  ...   33.240885    0.348958
# std       3.369578   30.552764  ...   11.760232    0.476951
# min       0.000000   44.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  141.000000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]
