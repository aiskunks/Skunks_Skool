# %%
import gym
env = gym.make('CartPole-v0')
env.reset()
# Out:
# array([-0.01383304,  0.02140001, -0.02875313, -0.0397425 ])

# %%
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
print(env.observation_space.high)
print(env.observation_space.low)
# Out:
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]

# %%
env = gym.make('Roulette-v0')
env.reset()
# Out:
# 0

# %%
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(38)
# Discrete(1)

# %%
env = gym.make('KellyCoinflip-v0')
env.reset()
# Out:
# (array([25.]), 300)

# %%
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(25000)
# Tuple(Box(0.0, 250.0, (1,), float32), Discrete(301))

# %% [markdown]
# If you have a continous action space, env.action_space will give you a Box object.

# %%
a = env.action_space
print(a)                
print(a.shape)
# Out:
# Discrete(25000)
# ()

# %%
o = env.observation_space
print(o)                
print(o.shape)
# Out:
# Tuple(Box(0.0, 250.0, (1,), float32), Discrete(301))
# None

# %%
env = gym.make('GuessingGame-v0')
env.reset()
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 0

# %%
print(env.action_space)
print(env.observation_space)
# Out:
# Box(-10000.0, 10000.0, (1,), float32)
# Discrete(4)

# %%
a = env.action_space
print(a)                
print(a.shape)
# Out:
# Box(-10000.0, 10000.0, (1,), float32)
# (1,)
