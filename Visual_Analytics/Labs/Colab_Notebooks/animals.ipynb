# %%
animals=['Aardvark','African Elephant','African Wild Dog','African Lion','Arabian (Dromedary) Camel Arctic Fox','Arctic Hare','Armadillo','Asian Elephant','Asian Lion','Aye-Aye','B','Baboon','Bactrian Camel','Beaver','Bear, Black','Beluga Whale','Bengal Tiger','Black Bear','Black-Footed Ferret','Black Rhinoceros','Blue Whale','Bobcat','Bottlenose Dolphin','Brown Bear','C','California Sea Lion','Caribou','Cheetah','Chimpanzee','Chipmunk','Clouded Leopard','Common Vampire Bat Common Wombat','Cottontail Rabbit','Cougar','Coyote','D','Dingo','Domestic Cat','Domestic Dog','Dugong','E','Eastern Gray Kangaroo','Elephant, African','Elephant, Asian','Elephant Seal','Elk (Moose)','F','Fennec Fox','Fossa','Fox, Fennec','Fur Seal','G','Gelada','Giant Anteater','Giant Panda','Giant River Otter','Gibbon','Giraffe','Golden Lion Tamarin','Gray Whale','Grizzly Bear','Groundhog','H','Harbor Porpoise','Hare','Hare, Arctic','Harp Seal','Hawaiian Monk Seal','Hedgehog','Hippopotamus','Horse','Howler Monkey','Humpback Whale','I','Impala','Indian Rhinoceros','J','Jaguar','K','Killer Whale, Orca','Kinkajou','Koala',' ','L','Leopard','Leopard Seal','Lion, African','Little Red Flying Fox','Llama','Lynx','M','Manatee','Mandrill','Meerkat','Mongoose','Moose (Elk)','Mountain Goat','Mountain Gorilla','Mountain Lion','Mouse Lemur','Musk-Ox','Mole Rat','N','Narwhal','North American River Otter','Nutria','O','Ocelot','Opossum','Orangutan','Orca Killer Whale','Ozark Big-Eared Bat',' ','P','Platypus','Polar Bear','Porcupine','Prairie Dog','Proboscis Monkey','Pronghorn','Przewalski’s Horse','Q','R','Raccoon','Red Fox','Red Kangaroo','Red Leaf Monkey','Red Panda','Red Uakari','Rhesus Monkey','Right Whale','Ringed Seal','Ring-Tailed Lemur','Rocky Mountain Bighorn Sheep','S','Sea Otter','Siberian Tiger','Sifaka','Skunk','Sloth Bear','Snow Leopard','Snowshoe Hare','Spectacled Bear','Sperm Whale','Spider Monkey','Spotted Hyena','Squirrel','Steller Sea Lion','Sumatran Rhinoceros','Sumatran Tiger','Sun Bear','Tapir','Tasmanian Devil','Thomson’s Gazelle','Three-Toed Sloth','Two-Toed Sloth','Wallaby','Walrus','Warthog','Water Buffalo','Weddell Seal','Western Lowland Gorilla','White Rhinoceros','Whale, Blue','Whale, Humpback','White-Eared Kob','White-Tailed Deer','Wildebeest','Wolf','Wolverine','Zebra','Carnivores','African lion','Cheetah','Dingo','Fennec Fox','Moose','Polar Bear','Sea Otter','Cetaceans','Blue Whale','Bottlenose Dolphin','Humpback Whale','Orca Killer Whale','Sperm Whale','Marsupials','Koala','Red kangaroo','Tasmanian Devil','Wallaby','Rodents','Beaver','Small Mammals','Meerkat','Primates','Ungulates','African Elephant','Asian Elephant','Giraffe','Hippopotamus','Horse','Arctic Hare','Black Bear','Llama']

# %%
animals[0:5]
# Out:
# ['Aardvark',
#  'African Elephant',
#  'African Wild Dog',
#  'African Lion',
#  'Arabian (Dromedary) Camel Arctic Fox']

# %%
print (len(animals))
# Out:
# 204
