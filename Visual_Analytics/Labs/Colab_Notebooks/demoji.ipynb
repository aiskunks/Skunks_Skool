# %%
# !pip install demoji

# %%
import demoji

# %%
demoji.download_codes()
# Out:
# ...
# ... OK (Got response in 0.17 seconds)
# Writing emoji data to /root/.demoji/codes.json ...
# ... OK

# %%
text='''word-relevant emojis ❤ to text ✨ with sometimes hilarious 😂 results 😏. Read more about its history 📚 and how it works'''

# %%
text
# Out:
# 'word-relevant emojis ❤ to text ✨ with sometimes hilarious 😂 results 😏. Read more about its history 📚 and how it works'

# %%
txt=demoji.findall(text)

# %%
txt
# Out:
# {'✨': 'sparkles',
#  '❤': 'red heart',
#  '📚': 'books',
#  '😂': 'face with tears of joy',
#  '😏': 'smirking face'}
