# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# Descriptive Statistics gives a brief overview of the charactieristics of dataset. We try to summarize a given dataset. It consists of two basic categories of measures: measures of central tendency and measures of variability (or spread).
#
# #### Usage:
# This notebook can infer statistics on any type of dataset and read it in format of CSV or Datasets. Refer to **Load the dataset**  part of the notebook to play around your custom dataset file
#
# #### Methods used in this notebook:
# - Detecting Categorical Features Vs Numerical Features
# - Missing data, such as features with empty values.
# - Mean of the features
# - Median of the features
# - Standard Deviation of the features
# - Visual of the Spread of the data
# - Labels treated as features, so that your model gets to peek at the right answer during training.
# - Features with values outside the range you expect.
#
# ### Libraries used
# - We use ``TensorFlow Data Validation(TFDV)`` to investigate and visualize the dataset. Understanding the input data is the most important step in building the data Science pipeline, as it can potentially harm model's prediction.
#
# #### Input:
# The input to this notebook is Tabular dataset.
#
# #### Output:
# Output of this notebook is statistics generated from the dataset.

# %% [markdown]
# ![Klee - Visual Analytics](https://github.com/nikbearbrown/Visual_Analytics/blob/main/IMG/Klee_Visual_Analytics.png?raw=true)
#
#
# YouTube - https://www.youtube.com/c/NikBearBrown
# GitHub - https://github.com/nikbearbrown/Visual_Analytics
# Kaggle - https://www.kaggle.com/nikbearbrown
# Klee.ai (Visual AI) - http://klee.ai

# %%
## install the library 
## uncomment the lines below if tenforflow is not installed

# print('Installing TensorFlow Data Validation')
# !pip install -q tensorflow_data_validation[visualization]

# %% [markdown]
# ### Restart the runtime

# %%
# imports 
import pandas as pd
import tensorflow as tf
import tensorflow_data_validation as tfdv

print('TF version: {}'.format(tf.__version__))
print('TFDV version: {}'.format(tfdv.version.__version__))
# Out:
# TF version: 2.7.0
# TFDV version: 1.5.0

# %% [markdown]
# ## Load the dataset

# %%
# loading dataset
url = "https://github.com/nikbearbrown/Visual_Analytics/raw/main/CSV/titanic_dataset.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## Visualizing the statistics:
#
# Here we use ``tfdv.generate_statistics_from_csv()`` to compute statistics for the training dataset. TFDV can compute descriptive statistics to provide a quick overview of the data. Other option is to use directly the dataframe ``tfdv.generate_statistics_from_dataframe()``
# - Numeric features and catagorical features are visualized separately, and that charts are displayed showing the distributions for each feature.
# - Features with missing or zero values display a percentage in red as a visual indicator that there may be issues with examples in those features. The percentage is the percentage of examples that have missing or zero values for that feature.
# - Click "expand" above the charts to change the display
# - Hovering over bars in the charts to display bucket ranges and counts
# - Switch between the log and linear scales, and notice how the log scale reveals much more detail
# - Select "quantiles" from the "Chart to show" menu, and hover over the markers to show the quantile percentages

# %%
# train_stats = tfdv.generate_statistics_from_csv(data_location=traintext)

titanic_stats = tfdv.generate_statistics_from_dataframe(df)

# %%
# dictionary format of the output
titanic_stats
# Out:
# datasets {
#   num_examples: 418
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 418
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 418
#       }
#       mean: 1100.5
#       std_dev: 120.66586095495279
#       min: 892.0
#       median: 1101.0
#       max: 1309.0
#       histograms {
#         buckets {
#           low_value: 892.0
#           high_value: 933.7
#           sample_count: 42.09260000000002
#         }
#         buckets {
#           low_value: 933.7
#           high_value: 975.4
#           sample_count: 41.67459999999997
#         }
#         buckets {
#           low_value: 975.4
#           high_value: 1017.1
#           sample_count: 42.09260000000002
#         }
#         buckets {
#           low_value: 1017.1
#           high_value: 1058.8
#           sample_count: 41.25659999999997
#         }
#         buckets {
#           low_value: 1058.8
#           high_value: 1100.5
#           sample_count: 41.67460000000002
#         }
#         buckets {
#           low_value: 1100.5
#           high_value: 1142.2
#           sample_count: 42.09260000000002
#         }
#         buckets {
#           low_value: 1142.2
#           high_value: 1183.9
#           sample_count: 41.25660000000002
#         }
#         buckets {
#           low_value: 1183.9
#           high_value: 1225.6
#           sample_count: 42.09259999999992
#         }
#         buckets {
#           low_value: 1225.6
#           high_value: 1267.3
#           sample_count: 41.67460000000001
#         }
#         buckets {
#           low_value: 1267.3
#           high_value: 1309.0
#           sample_count: 42.09260000000002
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 892.0
#           high_value: 933.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 933.0
#           high_value: 975.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 975.0
#           high_value: 1017.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1017.0
#           high_value: 1059.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1059.0
#           high_value: 1101.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1101.0
#           high_value: 1142.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1142.0
#           high_value: 1184.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1184.0
#           high_value: 1226.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1226.0
#           high_value: 1268.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1268.0
#           high_value: 1309.0
#           sample_count: 41.8
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "PassengerId"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 418
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 418
#       }
#       mean: 2.2655502392344498
#       std_dev: 0.8408299662625105
#       min: 1.0
#       median: 3.0
#       max: 3.0
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.2
#           sample_count: 106.6736
#         }
#         buckets {
#           low_value: 1.2
#           high_value: 1.4
#           sample_count: 0.08359999999999998
#         }
#         buckets {
#           low_value: 1.4
#           high_value: 1.6
#           sample_count: 0.08360000000000008
#         }
#         buckets {
#           low_value: 1.6
#           high_value: 1.8
#           sample_count: 0.08359999999999998
#         }
#         buckets {
#           low_value: 1.8
#           high_value: 2.0
#           sample_count: 0.08359999999999998
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.2
#           sample_count: 92.8796
#         }
#         buckets {
#           low_value: 2.2
#           high_value: 2.4000000000000004
#           sample_count: 0.08360000000000008
#         }
#         buckets {
#           low_value: 2.4000000000000004
#           high_value: 2.6
#           sample_count: 0.08359999999999988
#         }
#         buckets {
#           low_value: 2.6
#           high_value: 2.8
#           sample_count: 0.08359999999999988
#         }
#         buckets {
#           low_value: 2.8
#           high_value: 3.0
#           sample_count: 217.86159999999998
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 2.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 41.8
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Pclass"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 418
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 418
#       }
#       unique: 418
#       top_values {
#         value: "van Billiard, Master. Walter John"
#         frequency: 1.0
#       }
#       top_values {
#         value: "van Billiard, Master. James William"
#         frequency: 1.0
#       }
#       top_values {
#         value: "del Carlo, Mrs. Sebastiano (Argenia Genovesi)"
#         frequency: 1.0
#       }
#       top_values {
#         value: "de Messemaeker, Mr. Guillaume Joseph"
#         frequency: 1.0
#       }
#       top_values {
#         value: "de Brito, Mr. Jose Joaquim"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zakarian, Mr. Ortin"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zakarian, Mr. Mapriededer"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wright, Miss. Marion"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wittevrongel, Mr. Camille"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wirz, Mr. Albert"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wilson, Miss. Helen Alice"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Williams, Mr. Richard Norris II"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Willer, Mr. Aaron (Abi Weller\")\""
#         frequency: 1.0
#       }
#       top_values {
#         value: "Willard, Miss. Constance"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wilkes, Mrs. James (Ellen Needs)"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wiklund, Mr. Karl Johan"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Widener, Mrs. George Dunton (Eleanor Elkins)"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Widener, Mr. George Dunton"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wick, Mr. George Dennick"
#         frequency: 1.0
#       }
#       top_values {
#         value: "White, Mrs. John Stuart (Ella Holmes)"
#         frequency: 1.0
#       }
#       avg_length: 27.483253479003906
#       rank_histogram {
#         buckets {
#           label: "van Billiard, Master. Walter John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "van Billiard, Master. James William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "del Carlo, Mrs. Sebastiano (Argenia Genovesi)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "de Messemaeker, Mr. Guillaume Joseph"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "de Brito, Mr. Jose Joaquim"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "Zakarian, Mr. Ortin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Zakarian, Mr. Mapriededer"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "Wright, Miss. Marion"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "Wittevrongel, Mr. Camille"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Wirz, Mr. Albert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "Wilson, Miss. Helen Alice"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "Williams, Mr. Richard Norris II"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "Willer, Mr. Aaron (Abi Weller\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Willard, Miss. Constance"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Wilkes, Mrs. James (Ellen Needs)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "Wiklund, Mr. Karl Johan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "Widener, Mrs. George Dunton (Eleanor Elkins)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "Widener, Mr. George Dunton"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Wick, Mr. George Dennick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "White, Mrs. John Stuart (Ella Holmes)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Wheeler, Mr. Edwin Frederick\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Whabee, Mrs. George Joseph (Shawneene Abi-Saab)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "West, Miss. Barbara J"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "Wenzel, Mr. Linhart"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Wells, Mrs. Arthur Henry (Addie\" Dart Trevaskis)\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Wells, Master. Ralph Lester"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "Weisz, Mr. Leopold"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "Watt, Miss. Bertha J"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Warren, Mr. Frank Manley"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Warren, Mr. Charles William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Ware, Mrs. John James (Florence Louise Long)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Ware, Mr. William Jeffery"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "Ware, Mr. John James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Ware, Mr. Frederick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Walcroft, Miss. Nellie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Vendel, Mr. Olof Edvin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Veal, Mr. James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Vartanian, Mr. David"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Vander Planke, Mr. Julius"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Tucker, Mr. Gilbert Milligan Jr"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Touma, Miss. Maria Youssef"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Touma, Master. Georges Youssef"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Torfa, Mr. Assad"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Thomson, Mr. Alexander Morrison"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Thomas, Mrs. Alexander (Thamine Thelma\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Thomas, Mr. Tannous"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Thomas, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Thomas, Mr. Charles P"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "Tenglin, Mr. Gunnar Isidor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "Sweet, Mr. George Frederick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Swane, Mr. George"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Svensson, Mr. Johan Cervin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "Strilic, Mr. Ivan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "Straus, Mrs. Isidor (Rosalie Ida Blun)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Straus, Mr. Isidor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Storey, Mr. Thomas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "Stokes, Mr. Philip Joseph"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Stengel, Mrs. Charles Emil Henry (Annie May Morris)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Stengel, Mr. Charles Emil Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "Stanton, Mr. Samuel Ward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "Spinner, Mr. Henry John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "Spencer, Mr. William Augustus"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Spedden, Mr. Frederic Oakley"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "Spedden, Master. Robert Douglas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "Spector, Mr. Woolf"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "Snyder, Mrs. John Pillsbury (Nelle Stevenson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Snyder, Mr. John Pillsbury"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "Smyth, Miss. Julia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "Smith, Mrs. Lucien Philip (Mary Eloise Hughes)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "Smith, Mr. Lucien Philip"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "Sincock, Miss. Maude"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "Shine, Miss. Ellen Natalia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "Shaughnessy, Mr. Patrick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Schmidt, Mr. August"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "Schabert, Mrs. Paul (Emma Mock)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "Sap, Mr. Julius"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "Sandstrom, Miss. Beatrice Irene"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "Samaan, Mr. Hanna"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "Samaan, Mr. Elias"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "Salomon, Mr. Abraham L"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "Salander, Mr. Karl Johan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "Sage, Mrs. John (Annie Bullen)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "Sage, Mr. John George"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "Sage, Miss. Ada"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "Sage, Master. William Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "Saether, Mr. Simon Sivertsen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "Sadowitz, Mr. Harry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "Saade, Mr. Jean Nassr"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "Ryerson, Mrs. Arthur Larned (Emily Maria Borie)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "Ryerson, Mr. Arthur Larned"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "Ryerson, Master. John Borie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "Ryan, Mr. Edward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "Rowe, Mr. Alfred G"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "Rothschild, Mr. Martin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "Roth, Miss. Sarah A"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "Rosenshine, Mr. George (Mr George Thorne\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "Rosenbaum, Miss. Edith Louise"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "Rosblom, Miss. Salli Helena"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "Rogers, Mr. Reginald Harry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "Robins, Mr. Alexander A"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "Risien, Mrs. Samuel (Emma)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "Riordan, Miss. Johanna Hannah\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "Riihivouri, Miss. Susanna Juhantytar Sanni\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "Rice, Master. Albert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "Rheims, Mr. George Alexander Lucien"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "Reynolds, Mr. Harold J"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "Rasmussen, Mrs. (Lena Jacobsen Solvang)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "Quick, Miss. Winifred Vera"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "Pulbaum, Mr. Franz"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "Portaluppi, Mr. Emilio Ilario Giuseppe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "Pokrnic, Mr. Tome"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "Pokrnic, Mr. Mate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "Phillips, Mr. Escott Robert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "Phillips, Miss. Alice Frances Louisa"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "Petersen, Mr. Marius"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "Peter, Master. Michael J"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "Peruschitz, Rev. Joseph Maria"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "Peltomaki, Mr. Nikolai Johannes"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "Pedersen, Mr. Olaf"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "Pearce, Mr. Ernest"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "Peacock, Mrs. Benjamin (Edith Nile)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "Peacock, Miss. Treasteall"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "Peacock, Master. Alfred Edward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "Payne, Mr. Vivian Ponsonby"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "Parker, Mr. Clifford Richard"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "Palsson, Master. Paul Folke"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "Pallas y Castello, Mr. Emilio"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "Oxenham, Mr. Percy Thomas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "Ovies y Rodriguez, Mr. Servando"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "Ostby, Miss. Helene Ragnhild"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "Oreskovic, Miss. Jelka"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "Omont, Mr. Alfred Fernand"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 132
#           high_rank: 132
#           label: "Olsson, Mr. Oscar Wilhelm"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 133
#           high_rank: 133
#           label: "Olsen, Master. Artur Karl"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 134
#           high_rank: 134
#           label: "Oliva y Ocana, Dona. Fermina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 135
#           high_rank: 135
#           label: "O\'Keefe, Mr. Patrick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 136
#           high_rank: 136
#           label: "O\'Donoghue, Ms. Bridget"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 137
#           high_rank: 137
#           label: "O\'Connor, Mr. Patrick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 138
#           high_rank: 138
#           label: "Nourney, Mr. Alfred (Baron von Drachstedt\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 139
#           high_rank: 139
#           label: "Nilsson, Mr. August Ferdinand"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 140
#           high_rank: 140
#           label: "Nilsson, Miss. Berta Olivia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 141
#           high_rank: 141
#           label: "Niklasson, Mr. Samuel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 142
#           high_rank: 142
#           label: "Nieminen, Miss. Manta Josefina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 143
#           high_rank: 143
#           label: "Nesson, Mr. Israel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 144
#           high_rank: 144
#           label: "Naughton, Miss. Hannah"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 145
#           high_rank: 145
#           label: "Nasr, Mr. Mustafa"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 146
#           high_rank: 146
#           label: "Nancarrow, Mr. William Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 147
#           high_rank: 147
#           label: "Nakid, Mrs. Said (Waika Mary\" Mowad)\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 148
#           high_rank: 148
#           label: "Myles, Mr. Thomas Francis"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 149
#           high_rank: 149
#           label: "Murphy, Miss. Nora"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 150
#           high_rank: 150
#           label: "Mulvihill, Miss. Bertha E"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 151
#           high_rank: 151
#           label: "Moubarek, Mrs. George (Omine Amenia\" Alexander)\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 152
#           high_rank: 152
#           label: "Moore, Mr. Clarence Bloomfield"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 153
#           high_rank: 153
#           label: "Mock, Mr. Philipp Edmund"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 154
#           high_rank: 154
#           label: "Minkoff, Mr. Lazar"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 155
#           high_rank: 155
#           label: "Minahan, Mrs. William Edward (Lillian E Thorpe)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 156
#           high_rank: 156
#           label: "Miles, Mr. Frank"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 157
#           high_rank: 157
#           label: "Midtsjo, Mr. Karl Albert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 158
#           high_rank: 158
#           label: "McNeill, Miss. Bridget"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 159
#           high_rank: 159
#           label: "McNamee, Mrs. Neal (Eileen O\'Leary)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 160
#           high_rank: 160
#           label: "McGowan, Miss. Katherine"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 161
#           high_rank: 161
#           label: "McCrie, Mr. James Matthew"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 162
#           high_rank: 162
#           label: "McCrae, Mr. Arthur Gordon"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 163
#           high_rank: 163
#           label: "McCoy, Miss. Alicia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 164
#           high_rank: 164
#           label: "McCarthy, Miss. Catherine Katie\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 165
#           high_rank: 165
#           label: "McCaffry, Mr. Thomas Francis"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 166
#           high_rank: 166
#           label: "Maybery, Mr. Frank Hubert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 167
#           high_rank: 167
#           label: "Matinoff, Mr. Nicola"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 168
#           high_rank: 168
#           label: "Marvin, Mrs. Daniel Warner (Mary Graham Carmichael Farquarson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 169
#           high_rank: 169
#           label: "Mardirosian, Mr. Sarkis"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 170
#           high_rank: 170
#           label: "Mangiavacchi, Mr. Serafino Emilio"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 171
#           high_rank: 171
#           label: "Mallet, Mrs. Albert (Antoinette Magnin)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 172
#           high_rank: 172
#           label: "Malachard, Mr. Noel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 173
#           high_rank: 173
#           label: "Makinen, Mr. Kalle Edvard"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 174
#           high_rank: 174
#           label: "Mahon, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 175
#           high_rank: 175
#           label: "Mahon, Miss. Bridget Delia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 176
#           high_rank: 176
#           label: "Maguire, Mr. John Edward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 177
#           high_rank: 177
#           label: "MacKay, Mr. George William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 178
#           high_rank: 178
#           label: "Lyntakoff, Mr. Stanko"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 179
#           high_rank: 179
#           label: "Lundstrom, Mr. Thure Edvin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 180
#           high_rank: 180
#           label: "Lundin, Miss. Olga Elida"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 181
#           high_rank: 181
#           label: "Louch, Mr. Charles Alexander"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 182
#           high_rank: 182
#           label: "Loring, Mr. Joseph Holland"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 183
#           high_rank: 183
#           label: "Lockyer, Mr. Edward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 184
#           high_rank: 184
#           label: "Lithman, Mr. Simon"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 185
#           high_rank: 185
#           label: "Lingane, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 186
#           high_rank: 186
#           label: "Lines, Mrs. Ernest H (Elizabeth Lindsey James)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 187
#           high_rank: 187
#           label: "Linehan, Mr. Michael"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 188
#           high_rank: 188
#           label: "Lindstrom, Mrs. Carl Johan (Sigrid Posse)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 189
#           high_rank: 189
#           label: "Lindell, Mrs. Edvard Bengtsson (Elin Gerda Persson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 190
#           high_rank: 190
#           label: "Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lingrey\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 191
#           high_rank: 191
#           label: "Lennon, Miss. Mary"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 192
#           high_rank: 192
#           label: "Lefebre, Mrs. Frank (Frances)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 193
#           high_rank: 193
#           label: "Larsson-Rondberg, Mr. Edvard A"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 194
#           high_rank: 194
#           label: "Laroche, Miss. Louise"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 195
#           high_rank: 195
#           label: "Lane, Mr. Patrick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 196
#           high_rank: 196
#           label: "Lamb, Mr. John Joseph"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 197
#           high_rank: 197
#           label: "Lahtinen, Rev. William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 198
#           high_rank: 198
#           label: "Kreuchen, Miss. Emilie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 199
#           high_rank: 199
#           label: "Krekorian, Mr. Neshan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 200
#           high_rank: 200
#           label: "Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 201
#           high_rank: 201
#           label: "Klasen, Miss. Gertrud Emilia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 202
#           high_rank: 202
#           label: "Kink-Heilmann, Mrs. Anton (Luise Heilmann)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 203
#           high_rank: 203
#           label: "Kink-Heilmann, Mr. Anton"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 204
#           high_rank: 204
#           label: "Kink, Miss. Maria"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 205
#           high_rank: 205
#           label: "Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 206
#           high_rank: 206
#           label: "Kiernan, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 207
#           high_rank: 207
#           label: "Khalil, Mrs. Betros (Zahie Maria\" Elias)\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 208
#           high_rank: 208
#           label: "Khalil, Mr. Betros"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 209
#           high_rank: 209
#           label: "Kenyon, Mr. Frederick R"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 210
#           high_rank: 210
#           label: "Kennedy, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 211
#           high_rank: 211
#           label: "Kelly, Mr. James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 212
#           high_rank: 212
#           label: "Keeping, Mr. Edwin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 213
#           high_rank: 213
#           label: "Keane, Mr. Daniel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 214
#           high_rank: 214
#           label: "Katavelas, Mr. Vassilios (Catavelas Vassilios\")\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 215
#           high_rank: 215
#           label: "Karun, Mr. Franz"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 216
#           high_rank: 216
#           label: "Karnes, Mrs. J Frank (Claire Bennett)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 217
#           high_rank: 217
#           label: "Karlsson, Mr. Julius Konrad Eugen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 218
#           high_rank: 218
#           label: "Karlsson, Mr. Einar Gervasius"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 219
#           high_rank: 219
#           label: "Julian, Mr. Henry Forbes"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 220
#           high_rank: 220
#           label: "Jonsson, Mr. Nils Hilding"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 221
#           high_rank: 221
#           label: "Jones, Mr. Charles Cresson"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 222
#           high_rank: 222
#           label: "Johnston, Mrs. Andrew G (Elizabeth Lily\" Watson)\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 223
#           high_rank: 223
#           label: "Johnston, Master. William Arthur Willie\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 224
#           high_rank: 224
#           label: "Johansson, Mr. Nils"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 225
#           high_rank: 225
#           label: "Johansson Palmquist, Mr. Oskar Leander"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 226
#           high_rank: 226
#           label: "Jefferys, Mr. Ernest Wilfred"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 227
#           high_rank: 227
#           label: "Jefferys, Mr. Clifford Thomas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 228
#           high_rank: 228
#           label: "Ismay, Mr. Joseph Bruce"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 229
#           high_rank: 229
#           label: "Ilmakangas, Miss. Ida Livija"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 230
#           high_rank: 230
#           label: "Ilieff, Mr. Ylio"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 231
#           high_rank: 231
#           label: "Hyman, Mr. Abraham"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 232
#           high_rank: 232
#           label: "Howard, Mrs. Benjamin (Ellen Truelove Arman)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 233
#           high_rank: 233
#           label: "Howard, Mr. Benjamin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 234
#           high_rank: 234
#           label: "Howard, Miss. May Elizabeth"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 235
#           high_rank: 235
#           label: "Holthen, Mr. Johan Martin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 236
#           high_rank: 236
#           label: "Hold, Mrs. Stephen (Annie Margaret Hill)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 237
#           high_rank: 237
#           label: "Hocking, Mr. Samuel James Metcalfe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 238
#           high_rank: 238
#           label: "Hocking, Miss. Ellen Nellie\"\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 239
#           high_rank: 239
#           label: "Hirvonen, Mrs. Alexander (Helga E Lindqvist)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 240
#           high_rank: 240
#           label: "Hipkins, Mr. William Edward"
# ...
#         }
#         buckets {
#           low_value: 7.6292
#           high_value: 7.7958
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 7.7958
#           high_value: 8.05
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 8.05
#           high_value: 10.7083
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 10.7083
#           high_value: 14.4542
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 14.4542
#           high_value: 21.6792
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 21.6792
#           high_value: 26.55
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 26.55
#           high_value: 46.9
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 46.9
#           high_value: 79.2
#           sample_count: 41.699999999999996
#         }
#         buckets {
#           low_value: 79.2
#           high_value: 512.3292
#           sample_count: 41.699999999999996
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Fare"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 91
#         num_missing: 327
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 91
#       }
#       unique: 76
#       top_values {
#         value: "B57 B59 B63 B66"
#         frequency: 3.0
#       }
#       top_values {
#         value: "F4"
#         frequency: 2.0
#       }
#       top_values {
#         value: "E34"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C89"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C80"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C78"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C6"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C55 C57"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C31"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C23 C25 C27"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C116"
#         frequency: 2.0
#       }
#       top_values {
#         value: "C101"
#         frequency: 2.0
#       }
#       top_values {
#         value: "B45"
#         frequency: 2.0
#       }
#       top_values {
#         value: "A34"
#         frequency: 2.0
#       }
#       top_values {
#         value: "G6"
#         frequency: 1.0
#       }
#       top_values {
#         value: "F33"
#         frequency: 1.0
#       }
#       top_values {
#         value: "F2"
#         frequency: 1.0
#       }
#       top_values {
#         value: "F G63"
#         frequency: 1.0
#       }
#       top_values {
#         value: "F E57"
#         frequency: 1.0
#       }
#       top_values {
#         value: "F E46"
#         frequency: 1.0
#       }
#       avg_length: 4.07692289352417
#       rank_histogram {
#         buckets {
#           label: "B57 B59 B63 B66"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "F4"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "E34"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "C89"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "C80"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "C78"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "C6"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "C55 C57"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "C31"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "C23 C25 C27"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "C116"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "C101"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "B45"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "A34"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "G6"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "F33"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "F2"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "F G63"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "F E57"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "F E46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "F"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "E60"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "E52"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "E50"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "E46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "E45"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "E39 E41"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "E31"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "D43"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "D40"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "D38"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "D37"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "D34"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "D30"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "D28"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "D22"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "D21"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "D19"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "D15"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "D10 D12"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "D"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "C97"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "C86"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "C85"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "C7"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "C62 C64"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "C54"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "C53"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "C51"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "C46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "C39"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "C32"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "C28"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "C22 C26"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "C132"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "C130"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "C106"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "C105"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "B78"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "B71"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "B69"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "B61"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "B58 B60"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "B52 B54 B56"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "B51 B53 B55"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "B41"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "B36"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "B26"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "B24"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "B11"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "B10"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "A9"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "A29"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "A21"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "A18"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "A11"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "Cabin"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 418
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 41.8
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 418
#       }
#       unique: 3
#       top_values {
#         value: "S"
#         frequency: 270.0
#       }
#       top_values {
#         value: "C"
#         frequency: 102.0
#       }
#       top_values {
#         value: "Q"
#         frequency: 46.0
#       }
#       avg_length: 1.0
#       rank_histogram {
#         buckets {
#           label: "S"
#           sample_count: 270.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "C"
#           sample_count: 102.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Q"
#           sample_count: 46.0
#         }
#       }
#     }
#     path {
#       step: "Embarked"
#     }
#   }
# }

# %%
# visual output of the statistics from the dataset
tfdv.visualize_statistics(titanic_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## Schema for the data
# We use ``tfdv.infer_schema`` to create a schema for the data. It can be understood as documentation of the data, when multiple people are working on a particular dataset.
# The schema describes:
# - which features are expected to be present
# - their type
# - the number of values for a feature in each example
# - the presence of each feature across all examples
# - the expected domains of features.

# %%
schema = tfdv.infer_schema(statistics=titanic_stats)
tfdv.display_schema(schema=schema)
# Out:
#                  Type  Presence Valency      Domain
# Feature name
# 'PassengerId'     INT  required                   -
# 'Pclass'          INT  required                   -
# 'Name'          BYTES  required                   -
# 'Sex'          STRING  required               'Sex'
# 'Age'           FLOAT  optional  single           -
# 'SibSp'           INT  required                   -
# 'Parch'           INT  required                   -
# 'Ticket'        BYTES  required                   -
# 'Fare'          FLOAT  optional  single           -
# 'Cabin'        STRING  optional  single     'Cabin'
# 'Embarked'     STRING  required          'Embarked'
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Values
# Domain
# 'Sex'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'female', 'male'
# 'Cabin'     'A11', 'A18', 'A21', 'A29', 'A34', 'A9', 'B10', 'B11', 'B24', 'B26', 'B36', 'B41', 'B45', 'B51 B53 B55', 'B52 B54 B56', 'B57 B59 B63 B66', 'B58 B60', 'B61', 'B69', 'B71', 'B78', 'C101', 'C105', 'C106', 'C116', 'C130', 'C132', 'C22 C26', 'C23 C25 C27', 'C28', 'C31', 'C32', 'C39', 'C46', 'C51', 'C53', 'C54', 'C55 C57', 'C6', 'C62 C64', 'C7', 'C78', 'C80', 'C85', 'C86', 'C89', 'C97', 'D', 'D10 D12', 'D15', 'D19', 'D21', 'D22', 'D28', 'D30', 'D34', 'D37', 'D38', 'D40', 'D43', 'E31', 'E34', 'E39 E41', 'E45', 'E46', 'E50', 'E52', 'E60', 'F', 'F E46', 'F E57', 'F G63', 'F2', 'F33', 'F4', 'G6'
# 'Embarked'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'C', 'Q', 'S'

# %% [markdown]
# ## Pandas Analysis

# %% [markdown]
# continuous dataset

# %%
a = df.describe().T
a
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Pclass       418.0     2.265550    0.841838    1.00    1.0000     3.0000
# Age          332.0    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Pclass          3.00     3.0000
# Age            39.00    76.0000
# SibSp           1.00     8.0000
# Parch           0.00     9.0000
# Fare           31.50   512.3292

# %% [markdown]
# categorical columns

# %%
print(df.columns.to_list())
df.describe().columns.to_list()
# Out:
# ['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
categoricalColumns = list(set(df.columns.to_list()) - set(df.describe().columns.to_list()))
categoricalColumns
# Out:
# ['Ticket', 'Cabin', 'Sex', 'Name', 'Embarked']

# %%
b = pd.DataFrame(df[categoricalColumns].describe()).T
b
# Out:
#          count unique                 top freq
# Ticket     418    363            PC 17608    5
# Cabin       91     76     B57 B59 B63 B66    3
# Sex        418      2                male  266
# Name       418    418  Foley, Mr. William    1
# Embarked   418      3                   S  270

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
mergeddf = pd.concat( [a,b])

mergeddf["dataTypes"] = pd.DataFrame(df.dtypes)
mergeddf["NullValues"] = pd.DataFrame(df.isnull().sum())
mergeddf
# Out:
#             count         mean         std     min       25%        50%  \
# PassengerId   418  1100.500000  120.810458  892.00  996.2500  1100.5000
# Pclass        418     2.265550    0.841838    1.00    1.0000     3.0000
# Age           332    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp         418     0.447368    0.896760    0.00    0.0000     0.0000
# Parch         418     0.392344    0.981429    0.00    0.0000     0.0000
# Fare          417    35.627188   55.907576    0.00    7.8958    14.4542
# Ticket        418          NaN         NaN     NaN       NaN        NaN
# Cabin          91          NaN         NaN     NaN       NaN        NaN
# Sex           418          NaN         NaN     NaN       NaN        NaN
# Name          418          NaN         NaN     NaN       NaN        NaN
# Embarked      418          NaN         NaN     NaN       NaN        NaN
#
#                  75%        max unique                 top freq dataTypes  \
# PassengerId  1204.75  1309.0000    NaN                 NaN  NaN     int64
# Pclass          3.00     3.0000    NaN                 NaN  NaN     int64
# Age            39.00    76.0000    NaN                 NaN  NaN   float64
# SibSp           1.00     8.0000    NaN                 NaN  NaN     int64
# Parch           0.00     9.0000    NaN                 NaN  NaN     int64
# Fare           31.50   512.3292    NaN                 NaN  NaN   float64
# Ticket           NaN        NaN    363            PC 17608    5    object
# Cabin            NaN        NaN     76     B57 B59 B63 B66    3    object
# Sex              NaN        NaN      2                male  266    object
# Name             NaN        NaN    418  Foley, Mr. William    1    object
# Embarked         NaN        NaN      3                   S  270    object
#
#              NullValues
# PassengerId           0
# Pclass                0
# Age                  86
# SibSp                 0
# Parch                 0
# Fare                  1
# Ticket                0
# Cabin               327
# Sex                   0
# Name                  0
# Embarked              0

# %%
schema = pd.DataFrame()
schema = mergeddf.copy()
schema
# Out:
#             count         mean         std     min       25%        50%  \
# PassengerId   418  1100.500000  120.810458  892.00  996.2500  1100.5000
# Pclass        418     2.265550    0.841838    1.00    1.0000     3.0000
# Age           332    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp         418     0.447368    0.896760    0.00    0.0000     0.0000
# Parch         418     0.392344    0.981429    0.00    0.0000     0.0000
# Fare          417    35.627188   55.907576    0.00    7.8958    14.4542
# Ticket        418          NaN         NaN     NaN       NaN        NaN
# Cabin          91          NaN         NaN     NaN       NaN        NaN
# Sex           418          NaN         NaN     NaN       NaN        NaN
# Name          418          NaN         NaN     NaN       NaN        NaN
# Embarked      418          NaN         NaN     NaN       NaN        NaN
#
#                  75%        max unique                 top freq dataTypes  \
# PassengerId  1204.75  1309.0000    NaN                 NaN  NaN     int64
# Pclass          3.00     3.0000    NaN                 NaN  NaN     int64
# Age            39.00    76.0000    NaN                 NaN  NaN   float64
# SibSp           1.00     8.0000    NaN                 NaN  NaN     int64
# Parch           0.00     9.0000    NaN                 NaN  NaN     int64
# Fare           31.50   512.3292    NaN                 NaN  NaN   float64
# Ticket           NaN        NaN    363            PC 17608    5    object
# Cabin            NaN        NaN     76     B57 B59 B63 B66    3    object
# Sex              NaN        NaN      2                male  266    object
# Name             NaN        NaN    418  Foley, Mr. William    1    object
# Embarked         NaN        NaN      3                   S  270    object
#
#              NullValues
# PassengerId           0
# Pclass                0
# Age                  86
# SibSp                 0
# Parch                 0
# Fare                  1
# Ticket                0
# Cabin               327
# Sex                   0
# Name                  0
# Embarked              0

# %%
schema["FillMissingValues"] = schema.NullValues.apply(lambda x: "No" if x == 0 else "Yes") 
schema["RemoveFeature"]     = None 
schema["NormalizeData"]     = None

# %%
schema
# Out:
#            count        mean        std    min     25%    50%     75%    max  \
# patient    120.0   60.500000  34.785054    1.0   30.75   60.5   90.25  120.0
# bp_before  120.0  156.450000  11.389845  138.0  147.00  154.5  164.00  185.0
# bp_after   120.0  151.358333  14.177622  125.0  140.75  149.5  161.00  185.0
# sex          120         NaN        NaN    NaN     NaN    NaN     NaN    NaN
# agegrp       120         NaN        NaN    NaN     NaN    NaN     NaN    NaN
#
#           unique    top freq dataTypes  NullValues FillMissingValues  \
# patient      NaN    NaN  NaN     int64           0                No
# bp_before    NaN    NaN  NaN     int64           0                No
# bp_after     NaN    NaN  NaN     int64           0                No
# sex            2   Male   60    object           0                No
# agegrp         3  30-45   40    object           0                No
#
#           RemoveFeature NormalizeData
# patient            None          None
# bp_before          None          None
# bp_after           None          None
# sex                None          None
# agegrp             None          None

# %%
pd.DataFrame(schema.FillMissingValues)
# Out:
#             FillMissingValues
# PassengerId                No
# Pclass                     No
# Age                       Yes
# SibSp                      No
# Parch                      No
# Fare                      Yes
# Ticket                     No
# Cabin                     Yes
# Sex                        No
# Name                       No
# Embarked                   No

# %%
schema.index[schema['FillMissingValues'] == "No"].tolist()
# Out:
# ['PassengerId',
#  'Pclass',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Sex',
#  'Name',
#  'Embarked']
